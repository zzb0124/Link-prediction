# %%
import graph_tool as gt
from graph_tool import inference,draw

# %%
G = gt.load_graph_from_csv('ants_data.csv',eprop_types=["int","int"],
                           eprop_names=["StartTime","EndTime"],skip_first=True)

# %%
state = gt.inference.minimize_blockmodel_dl(G,state_args=dict(deg_corr=False))

# %%
state.draw()
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7fa75f9dca30, at 0x7fa75f987880>

# %%
state2 = gt.inference.minimize_nested_blockmodel_dl(G,state_args=dict(deg_corr=False))

# %%
state2.draw()
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x7fa75f9dca30, at 0x7fa75dcb2850>,
#  <Graph object, directed, with 151 vertices and 150 edges, at 0x7fa75f984af0>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7fa75f984af0, at 0x7fa75f9b6250>)
